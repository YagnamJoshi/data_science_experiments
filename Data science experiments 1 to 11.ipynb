# %% [markdown]
# #### Yagnam Joshi
# #### TY CSE 17
# #### 1032220133

# %% [markdown]
# # Data science

# %% [markdown]
# ## Experiment 1
# ### Title: Loading, merging / the data set using data set obtained from UCI ML repository

# %% [markdown]
# ### Mount google drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Import first dataset

# %%
df1 = pd.read_csv('student_info.csv')
df1
# Out:
#    Student ID     Name  Age Grade
# 0         101    Alice   20     A
# 1         102      Bob   21     B
# 2         103  Charlie   19     A
# 3         104    David   22     C
# 4         105      Eve   20     B

# %% [markdown]
# ### Import second dataset

# %%
df2 = pd.read_csv('student_scores.csv')
df2
# Out:
#    Student ID  Math Score  English Score  Science Score
# 0         101          85             78             92
# 1         102          76             88             81
# 2         103          90             95             89
# 3         104          65             70             75
# 4         105          80             82             87

# %% [markdown]
# ### merge the dataset

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#    Student ID     Name  Age Grade  Student ID  Math Score  English Score  \
# 0         101    Alice   20     A         101          85             78
# 1         102      Bob   21     B         102          76             88
# 2         103  Charlie   19     A         103          90             95
# 3         104    David   22     C         104          65             70
# 4         105      Eve   20     B         105          80             82
#
#    Science Score
# 0             92
# 1             81
# 2             89
# 3             75
# 4             87

# %% [markdown]
# ## Experiment 2
# ### Title:  Data Preprocessing-Cleaning the data set using data set obtained from UCI ML  repository

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_csv('grapes_new.csv')
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
# ...

# %%
df.head()
# Out:
#    COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0           120.53  elliptical         16.73        14.23            1.71
# 1           112.57  elliptical         20.30        13.20            1.78
# 2           120.78  elliptical         20.81        13.16            2.36
# 3           134.17  elliptical         19.47        14.37            1.95
# 4           112.19       round         17.57        13.24            2.59
#
#     ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  ...  \
# 0  2.43               15.6                127           2.80        3.06  ...
# 1  2.14               11.2                100           2.65        2.76  ...
# 2  2.67               18.6                101           2.80        3.24  ...
# 3  2.50               16.8                113           3.85        3.49  ...
# 4  2.87               21.0                118           2.80        2.69  ...
#
# ...

# %%
df.tail()
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 189  2.17               21.0                 85           2.60        2.65
# 190  2.29                NaN                 86           2.74        3.15
# 191  2.78               28.5                 92           2.13        2.24
# 192  2.30               24.5                 88           2.22        2.45
# 193  2.38                NaN                 80           2.10        1.75
#
# ...

# %%
df.describe(include="all")
# Out:
#         COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  \
# count        194.000000         194    192.000000   191.000000
# unique              NaN           2           NaN          NaN
# top                 NaN  elliptical           NaN          NaN
# freq                NaN         123           NaN          NaN
# mean         116.882113         NaN     21.512604    13.024241
# std           14.333204         NaN      2.386562     0.809621
# min           93.000000         NaN     16.170000    11.030000
# 25%          105.470000         NaN     20.315000    12.370000
# 50%          114.910000         NaN     21.820000    13.050000
# 75%          124.060000         NaN     23.345000    13.685000
# max          167.000000         NaN     25.200000    14.830000
#
#         MALIC_ACID_PER         ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  \
# count       194.000000  194.000000         188.000000         194.000000
# ...

# %% [markdown]
# ### get more info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COLOR_INTENSITY    194 non-null    float64
#  1   SHAPE              194 non-null    object
#  2   RIPENESS_PER       192 non-null    float64
#  3   ALCOHOL_PER        191 non-null    float64
#  4   MALIC_ACID_PER     194 non-null    float64
#  5   ASH                194 non-null    float64
#  6   ALCALINITY_OF_ASH  188 non-null    float64
#  7   MAGNESIUM_MEASURE  194 non-null    int64
#  8   TOTAL_PHENOLS      194 non-null    float64
#  9   FLAVANOIDS         194 non-null    float64
#  10  PROANTHOCYANINS    194 non-null    float64
#  11  HUE                192 non-null    float64
#  12  PROLINE            194 non-null    int64
#  13  TEMPERATURE        194 non-null    float64
#  14  AVG_HUMIDITY       194 non-null    float64
# ...

# %% [markdown]
# ### visualize data for better understanding

# %%
# List of all features
features = df.columns.tolist()

# Plot histograms for each feature
plt.figure(figsize=(20, 15))
for i, feature in enumerate(features):
    plt.subplot(6, 4, i + 1)
    df[feature].hist(bins=20, edgecolor='black')
    plt.title(f'Histogram of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### checking for null values

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %% [markdown]
# ### removing null values

# %%
df=df.dropna()

# %%
# # supposing you want to replace them example:
# mean_value = df['WATER_O2_PER'].mean()
# df['WATER_O2_PER'].fillna(mean_value, inplace=True)

# %% [markdown]
# ### check if null values are removed

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         0
# ALCOHOL_PER          0
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    0
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  0
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         0
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
plt.figure(figsize=(20, 15))
for i, feature in enumerate(numeric_columns):
    plt.subplot(6, 4, i + 1)
    sns.boxplot(x=df[feature])
    plt.title(f'Box plot of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### removing outliers

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
Q1 = df[numeric_columns].quantile(0.25)
Q3 = df[numeric_columns].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[numeric_columns] < (Q1 - 1.5 * IQR)) | (df[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 183           118.07  elliptical         19.79        14.39            1.87
# 186           130.51  elliptical         16.87        13.86            1.35
# 188           102.60  elliptical         21.78        11.87            4.31
# 189           102.34  elliptical         21.23        12.07            2.16
# 192            98.30  elliptical         21.95        12.37            1.63
#
# ...

# %% [markdown]
# ### checking if outliers are removed

# %%
# Plot box plots for each numeric feature
plt.figure(figsize=(20, 15))
for i, feature in enumerate(numeric_columns):
    plt.subplot(6, 4, i + 1)
    sns.boxplot(x=df[feature])
    plt.title(f'Box plot of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Experiment 3
# ### Title: Data Preprocessing-Applying, encoding techniques using data set obtained from  UCI ML repository

# %% [markdown]
# ### Import encoding libraries

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# ### Add encoders

# %%
label_encoder = LabelEncoder()
#onehot_encoder = OneHotEncoder(sparse=False)

# %% [markdown]
# ### Perform label encoding on class

# %%
df['CLASS'] = label_encoder.fit_transform(df['CLASS'])
df.head()
# Out:
#    COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0           120.53  elliptical         16.73        14.23            1.71
# 1           112.57  elliptical         20.30        13.20            1.78
# 2           120.78  elliptical         20.81        13.16            2.36
# 3           134.17  elliptical         19.47        14.37            1.95
# 4           112.19       round         17.57        13.24            2.59
#
#     ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  ...  \
# 0  2.43               15.6                127           2.80        3.06  ...
# 1  2.14               11.2                100           2.65        2.76  ...
# 2  2.67               18.6                101           2.80        3.24  ...
# 3  2.50               16.8                113           3.85        3.49  ...
# 4  2.87               21.0                118           2.80        2.69  ...
#
# ...

# %% [markdown]
# ### Perform one hot encoding

# %%
onehot_encoder_shape = OneHotEncoder(sparse_output=False)
shape_encoded = onehot_encoder_shape.fit_transform(df[['SHAPE']])
shape_encoded_df = pd.DataFrame(shape_encoded, columns=onehot_encoder_shape.get_feature_names_out(['SHAPE']))

onehot_encoder_soil = OneHotEncoder(sparse_output=False)
soil_type_encoded = onehot_encoder_soil.fit_transform(df[['SOIL_TYPE']])
soil_type_encoded_df = pd.DataFrame(soil_type_encoded, columns=onehot_encoder_soil.get_feature_names_out(['SOIL_TYPE']))

# Concatenate the original dataframe with the one-hot encoded columns
df_encoded = pd.concat([df, shape_encoded_df, soil_type_encoded_df], axis=1)
df_encoded.drop(['SHAPE', 'SOIL_TYPE'], axis=1, inplace=True)

# Display the updated dataframe
df_encoded.head()
# Out:
#    COLOR_INTENSITY  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER   ASH  \
# 0           120.53         16.73        14.23            1.71  2.43
# 1           112.57         20.30        13.20            1.78  2.14
# 2           120.78         20.81        13.16            2.36  2.67
# 3           134.17         19.47        14.37            1.95  2.50
# 4           112.19         17.57        13.24            2.59  2.87
#
#    ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 0               15.6              127.0           2.80        3.06
# 1               11.2              100.0           2.65        2.76
# 2               18.6              101.0           2.80        3.24
# 3               16.8              113.0           3.85        3.49
# 4               21.0              118.0           2.80        2.69
#
#    PROANTHOCYANINS  ...  AVG_HUMIDITY  FERT_NITRO_PER  WATER_O2_PER  WATER_PH  \
# ...

# %%
### Spliting the dataset

# %%
from sklearn.model_selection import train_test_split
X = df_encoded.drop(columns=['CLASS'])  # Features
y = df_encoded['CLASS']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Checking null values in splited dataset
print("Y test:",y_train.isnull().sum())
print("Y train:",y_test.isnull().sum())
# Out:
# Y test: 23
# Y train: 4

# %%
# Treating them
# Calculate the mean of the non-null values in y_train
mean_y_train = y_train.mean()

# Replace NaN values in y_train with the calculated mean
y_train.fillna(mean_y_train, inplace=True)

# Calculate the mean of the non-null values in y_test
mean_y_test = y_test.mean()

# Replace NaN values in y_test with the calculated mean
y_test.fillna(mean_y_test, inplace=True)

# %%
# Checking null values again
print("Y test:",y_train.isnull().sum())
print("Y train:",y_test.isnull().sum())
# Out:
# Y test: 0
# Y train: 0

# %% [markdown]
# ## Experiment 4
# ### Data Preprocessing-Normalizing, scaling, balancing data set using data set  obtained from UCI ML repository

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
min_max_scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both X_train and X_test
X_train_scaled = min_max_scaler.fit_transform(X_train)
X_test_scaled = min_max_scaler.transform(X_test)

# Again, y_train and y_test typically do not require scaling.

# %%
# from sklearn.preprocessing import StandardScaler

# Initialize the scaler
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# # y_train and y_test do not need scaling since they are typically labels (classifications)

# %% [markdown]
# ### Check if dataset is balanaced

# %%
# df_encoded['CLASS'].value_counts()
print("Values in ytrain")
print(y_train.value_counts())
# Out:
# Values in ytrain
# CLASS
# 2.000000    40
# 0.000000    39
# 1.000000    33
# 1.008929    23
# Name: count, dtype: int64

# %% [markdown]
# ### Balancing the datset

# %%
print(y_train.head())
print(y_train.dtype)
# If y_train is continuous and should be categorical, convert it to integers
y_train = y_train.astype(int)

# Or use binning to convert continuous to discrete categories
# Example: Binning continuous values into discrete bins
y_train = pd.cut(y_train, bins=3, labels=False)
# Out:
# 110    1.000000
# 48     0.000000
# 91     1.008929
# 141    2.000000
# 98     1.008929
# Name: CLASS, dtype: float64
# float64

# %%
from imblearn.over_sampling import RandomOverSampler
oversampler = RandomOverSampler(random_state=42)
X_train_balanced, y_train_balanced = oversampler.fit_resample(X_train_scaled, y_train)

# %% [markdown]
# ### Checking the dataset again

# %%
print("Values in ytrain")
print(y_train_balanced.value_counts())
# Out:
# Values in ytrain
# CLASS
# 1    56
# 0    56
# 2    56
# Name: count, dtype: int64

# %% [markdown]
# ## Experiment 5
# ### Title: Data Visualization using Matplotlib library part-l using data set obtained from UCI ML repository

# %% [markdown]
# ### Line chart
# #### added:
# ##### Axis label
# ##### Legend and chart title
# ##### line marker

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['COLOR_INTENSITY'], df['SHAPE'], marker='o', linestyle='-', color='b', label='Shape vs Intensity')
plt.title("Intensity vs shape")
plt.xlabel('Intensity')
plt.ylabel('Shape')
plt.legend()

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='CLASS', data=df, palette='viridis')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Count Plot of Class')
plt.show()
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_25824\3139535426.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='CLASS', data=df, palette='viridis')

# %% [markdown]
# ## Experiment 6
# ### Title: Data Visualization using Matplotlib library part-2 using data set obtained from UCI  ML repository

# %% [markdown]
# ### Scatter plot
# #### Added
# ##### hues

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='COLOR_INTENSITY', y='RIPENESS_PER', hue='CLASS', data=df, palette='viridis')
plt.xlabel('Color Intensity')
plt.ylabel('Ripeness Percentage')
plt.title('Scatter Plot of Ripeness vs. Color Intensity')
plt.legend(title='Class')

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['ALCOHOL_PER'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Alcohol Percentage')
plt.ylabel('Frequency')
plt.title('Histogram of Alcohol Percentage')
# Out:
# Text(0.5, 1.0, 'Histogram of Alcohol Percentage')

# %% [markdown]
# ### Bar plot

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='SHAPE', y='MAGNESIUM_MEASURE', data=df, estimator='mean', palette='viridis')
plt.xlabel('Shape')
plt.ylabel('Average Magnesium Measure')
plt.title('Bar Plot of Average Magnesium Measure by Shape')
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_25824\2705596330.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='SHAPE', y='MAGNESIUM_MEASURE', data=df, estimator='mean', palette='viridis')
# Text(0.5, 1.0, 'Bar Plot of Average Magnesium Measure by Shape')

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='SHAPE', y='FLAVANOIDS', data=df, palette='viridis')
plt.xlabel('Shape')
plt.ylabel('Flavanoids')
plt.title('Box Plot of Flavanoids by Shape')
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_25824\1296706970.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='SHAPE', y='FLAVANOIDS', data=df, palette='viridis')
# Text(0.5, 1.0, 'Box Plot of Flavanoids by Shape')

# %% [markdown]
# ## Experiment 7 & 8
# ### Apply filter feature selection Techniques Part-l & 2 using data set obtained from UCI ML repository

# %% [markdown]
# ### filter methods

# %%
# Remove null values first
# Convert to DataFrame
X_train_balanced = pd.DataFrame(X_train_balanced)

# Drop rows with missing values
X_train_balanced = X_train_balanced.dropna()
y_train_balanced = y_train_balanced[X_train_balanced.index]

# %% [markdown]
# ### Information gain

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X_train_balanced, y_train_balanced)
mi_df = pd.DataFrame({'Feature': X_train_balanced.columns, 'Mutual Information': mutual_info})
threshold = 0.01
selected_features = mi_df[mi_df['Mutual Information'] > threshold]
num_selected_features = len(selected_features)
print(f"Number of selected features: {num_selected_features}")
print(f"Selected features:\n{selected_features}")
# Out:
# Number of selected features: 20
# Selected features:
#     Feature  Mutual Information
# 0         0            0.413037
# 1         1            0.838062
# 2         2            0.286645
# 3         3            0.361215
# 4         4            0.137486
# 5         5            0.299682
# 6         6            0.203915
# 7         7            0.529423
# 8         8            0.699080
# 9         9            0.397115
# 10       10            0.442882
# 11       11            0.469829
# 12       12            0.883414
# 13       13            0.162946
# 14       14            0.795187
# 15       15            0.841836
# 16       16            0.650590
# 17       17            0.254357
# 20       20            0.032926
# 21       21            0.078304

# %% [markdown]
# ### Chi square

# %%
from sklearn.feature_selection import chi2
chi_scores, p_values = chi2(X_train_balanced, y_train_balanced)
chi_df = pd.DataFrame({'Feature': X_train_balanced.columns, 'Chi-Square': chi_scores, 'P-Value': p_values})
chi_df = chi_df.sort_values(by='Chi-Square', ascending=False)
chi_square_threshold = 10 
p_value_threshold = 0.05 
selected_features_chi = chi_df[(chi_df['Chi-Square'] > chi_square_threshold) & (chi_df['P-Value'] < p_value_threshold)]
num_selected_features_chi = len(selected_features_chi)
print(f"Number of selected features based on Chi-Square and p-value thresholds: {num_selected_features_chi}")
print(f"Selected features:\n{selected_features_chi}")
# Out:
# Number of selected features based on Chi-Square and p-value thresholds: 5
# Selected features:
#     Feature  Chi-Square   P-Value
# 12       12   22.482706  0.000013
# 15       15   16.495803  0.000262
# 8         8   16.206810  0.000303
# 1         1   15.808710  0.000369
# 11       11   11.070520  0.003945

# %% [markdown]
# ### Pearson coefficient

# %%
import pandas as pd
import numpy as np

# Step 1: Calculate Pearson correlation between each feature and the target
correlation_scores = X_train_balanced.corrwith(y_train_balanced)

# Step 2: Create a DataFrame to store feature names and their correlation coefficients
corr_df = pd.DataFrame({'Feature': X_train_balanced.columns, 'Pearson_Correlation': correlation_scores})

# Step 3: Set a correlation threshold for feature selection
correlation_threshold = 0.1  # Adjust this threshold as needed

# Step 4: Filter features that have an absolute correlation coefficient above the threshold
selected_features_corr = corr_df[abs(corr_df['Pearson_Correlation']) > correlation_threshold]

# Step 5: Sort the features based on the Pearson correlation (absolute values)
selected_features_corr = selected_features_corr.sort_values(by='Pearson_Correlation', ascending=False)

# Step 6: Display the number of selected features and the selected feature names
num_selected_features_corr = len(selected_features_corr)
print(f"Number of selected features based on Pearson correlation threshold: {num_selected_features_corr}")
print(f"Selected features:\n{selected_features_corr}")
# Out:
# Number of selected features based on Pearson correlation threshold: 18
# Selected features:
#     Feature  Pearson_Correlation
# 1         1             0.651890
# 5         5             0.584175
# 12       12             0.578095
# 13       13             0.303164
# 17       17             0.266601
# 20       20             0.195538
# 16       16             0.140681
# 21       21            -0.195538
# 4         4            -0.280917
# 0         0            -0.335156
# 6         6            -0.449067
# 14       14            -0.449302
# 9         9            -0.450697
# 7         7            -0.588457
# 15       15            -0.597754
# 8         8            -0.614653
# 2         2            -0.660372
# 11       11            -0.737788

# %%
selected_feature_names = selected_features_corr['Feature'].tolist()
selected_X_train = X_train_balanced[selected_feature_names]

# Step 2: Calculate the correlation matrix for the selected features
correlation_matrix_selected = selected_X_train.corr()

# Step 3: Plot the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix_selected, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar_kws={'shrink': .8})
plt.title('Correlation Matrix for Selected Features')
plt.show()

# %% [markdown]
# ## Experiment 9 & 10
# ### Apply wrapper feature selection Techniques Part-1 & 2 using data set obtained from UCI ML repository

# %% [markdown]
# ### Wrapper methods

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.metrics import accuracy_score
from mlxtend.feature_selection import SequenatialFeatureSelector as SFS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[95], line 4
#       2 from sklearn.feature_selection import RFE
#       3 from sklearn.metrics import accuracy_score
# ----> 4 from mlxtend.feature_selection import SequenatialFeatureSelector as SFS
#
# ImportError: cannot import name 'SequenatialFeatureSelector' from 'mlxtend.feature_selection' (C:\Users\joshi\anaconda3\Lib\site-packages\mlxtend\feature_selection\__init__.py)

# %% [markdown]
# ### Forward selection

# %%
# Forward Selection
# Sequential Forward Selection (sfs)
model = LogisticRegression()
sfs = SFS(model, 
          k_features='best', 
          forward=True, 
          floating=False, 
          scoring='accuracy',
          cv=5)

sfs = sfs.fit(X_train_balanced, y_train_balanced)

# Features selected by Forward Selection
selected_features_forward = list(sfs.k_feature_names_)
num_selected_features_forward = len(selected_features_forward)

print(f"Number of features selected by Forward Selection: {num_selected_features_forward}")
print(f"Selected features:\n{selected_features_forward}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 4
#       1 # Forward Selection
#       2 # Sequential Forward Selection (sfs)
#       3 model = LogisticRegression()
# ----> 4 sfs = SFS(model,
#       5           k_features='best',
#       6           forward=True,
#       7           floating=False,
#       8           scoring='accuracy',
#       9           cv=5)
#      11 sfs = sfs.fit(X_train_balanced, y_train_balanced)
#      13 # Features selected by Forward Selection
#
# NameError: name 'SFS' is not defined

# %% [markdown]
# ### Backward elimination

# %%
rfe = RFE(estimator=model, n_features_to_select=1, step=1)
rfe = rfe.fit(X_train_balanced, y_train_balanced)

# Get the ranking of the features
ranking = rfe.ranking_
selected_features_backward = X_train_balanced.columns[ranking == 1]
num_selected_features_backward = len(selected_features_backward)

print(f"\nNumber of features selected by Backward Elimination: {num_selected_features_backward}")
print(f"Selected features:\n{selected_features_backward.tolist()}")
# Out:
# Number of features selected by Backward Elimination: 1
# Selected features:
# [12]

# %% [markdown]
# ### RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier  # You can change this to any other model
import pandas as pd

# Step 1: Initialize the model and RFE
model = RandomForestClassifier(random_state=42)  # Replace with your model of choice
rfe = RFE(estimator=model, n_features_to_select=10)  # Choose the number of features to select

# Step 2: Fit RFE to the data
rfe.fit(X_train_balanced, y_train_balanced)

# Step 3: Get the selected feature names
selected_features_rfe = X_train_balanced.columns[rfe.support_]

# Step 4: Create a DataFrame with the selected features
rfe_df = pd.DataFrame({'Feature': X_train_balanced.columns, 'Selected': rfe.support_, 'Ranking': rfe.ranking_})
rfe_df = rfe_df[rfe_df['Selected'] == True]  # Filter the selected features

# Step 5: Display the selected features
num_selected_features_rfe = len(selected_features_rfe)
print(f"Number of selected features based on RFE: {num_selected_features_rfe}")
print(f"Selected features:\n{rfe_df}")
# Out:
# Number of selected features based on RFE: 10
# Selected features:
#     Feature  Selected  Ranking
# 0         0      True        1
# 1         1      True        1
# 2         2      True        1
# 7         7      True        1
# 8         8      True        1
# 10       10      True        1
# 12       12      True        1
# 14       14      True        1
# 15       15      True        1
# 16       16      True        1

# %% [markdown]
# ### RFE CV

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier  # You can change this to any other model
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Initialize the model and RFECV
model = RandomForestClassifier(random_state=42)  # Replace with your model of choice
rfecv = RFECV(estimator=model, step=1, cv=5, scoring='accuracy')  # Use k-fold cross-validation

# Step 2: Fit RFECV to the data
rfecv.fit(X_train_balanced, y_train_balanced)

# Step 3: Get the selected feature names
selected_features_rfecv = X_train_balanced.columns[rfecv.support_]

# Step 4: Create a DataFrame with the selected features
rfecv_df = pd.DataFrame({'Feature': X_train_balanced.columns, 'Selected': rfecv.support_, 'Ranking': rfecv.ranking_})
rfecv_df = rfecv_df[rfecv_df['Selected'] == True]  # Filter the selected features

# Step 5: Display the selected features
num_selected_features_rfecv = len(selected_features_rfecv)
print(f"Number of selected features based on RFECV: {num_selected_features_rfecv}")
print(f"Selected features:\n{rfecv_df}")

# Step 6: Plot the number of features selected against cross-validation scores
plt.figure(figsize=(10, 6))
plt.xlabel("Number of Features Selected")
plt.ylabel("Cross-Validation Score (Accuracy)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.title("RFECV - Number of Features vs. Cross-Validation Score")
plt.show()
# Out:
# Number of selected features based on RFECV: 3
# Selected features:
#     Feature  Selected  Ranking
# 1         1      True        1
# 12       12      True        1
# 15       15      True        1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 29
#      27 plt.xlabel("Number of Features Selected")
#      28 plt.ylabel("Cross-Validation Score (Accuracy)")
# ---> 29 plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
#      30 plt.title("RFECV - Number of Features vs. Cross-Validation Score")
#      31 plt.show()
#
# AttributeError: 'RFECV' object has no attribute 'grid_scores_'

# %% [markdown]
# ## Experiment 11
# ###  Using different ML supervised Classifiers using data set obtained from UCI ML  repository

# %% [markdown]
# #### Import libaries

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# #### Bagging
# ##### Randomforest

# %%
y_test = y_test.astype(int)

# %%
# Create a Bagging classifier with Decision Trees
bagging_clf = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging_clf.fit(X_train_balanced, y_train_balanced)

# Predict and evaluate
y_pred = bagging_clf.predict(X_test)
print("Bagging Classifier Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Bagging Classifier Accuracy: 0.2391304347826087
# C:\Users\joshi\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but BaggingClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# #### Boosting
# ##### Xgboost

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")
X_train_balanced = imputer.fit_transform(X_train_balanced)
X_test = imputer.transform(X_test)
# Out:
# C:\Users\joshi\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(

# %%
# Create an AdaBoost classifier with Decision Trees as weak learners
boosting_clf = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=50, random_state=42)
boosting_clf.fit(X_train_balanced, y_train_balanced)

# Predict and evaluate
y_pred = boosting_clf.predict(X_test)
print("Boosting Classifier Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Boosting Classifier Accuracy: 0.391304347826087
# C:\Users\joshi\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %% [markdown]
# #### Stacking
# ##### Logistic regressor and KNN

# %%
# Define base models
estimators = [
    ('knn', KNeighborsClassifier(n_neighbors=5)),
    ('svm', SVC(kernel='linear', probability=True))
]

# Meta-model
stacking_clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())

# Fit and evaluate
stacking_clf.fit(X_train_balanced, y_train_balanced)
y_pred = stacking_clf.predict(X_test)
print("Stacking Classifier Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# C:\Users\joshi\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\joshi\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Stacking Classifier Accuracy: 0.30434782608695654

# %% [markdown]
# ### Bagging: While Bagging is good for reducing overfitting by averaging multiple models on different data samples, it might not be the best for capturing the complex patterns in my data. It works well on high variance but may not boost performance enough when the model needs to focus on harder-to-predict instances.
#
# ### Boosting: For my dataset, Boosting works the best because it focuses on correcting the errors made by previous models, which helps improve accuracy, especially when the data has complex relationships. Boosting reduces bias and often improves performance on difficult-to-classify cases, leading to better overall accuracy.
#
# ### Stacking: While Stacking could be effective by combining multiple model predictions, it often requires a good mix of base models and can be computationally expensive, which may not always lead to the best performance for my case.
#
# ## Why Boosting works best for me: In my dataset, Boosting provides the best accuracy because it focuses on correcting errors and refining predictions. Since my data might have complex patterns or harder-to-predict examples, Boosting’s sequential approach helps improve performance by giving more attention to those difficult cases, leading to a better final model.
